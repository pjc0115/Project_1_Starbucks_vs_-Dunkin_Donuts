# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st


starbucks_data_path = "../desktop/Starbucks_US_2018_11_12.csv"
#estimate_pop_path = "../desktop/nst-est2020-popchg2010-2020.csv"

starbucks_data = pd.read_csv(starbucks_data_path)
#estimate_pop = pd.read_csv(estimate_pop_path)
starbucks_data.head()

#startbucks_df

#starbucks_data.columns
# Out:
#                            name  \
# 0    Val Vista & Baseline, Mesa
# 1    Val Vista & Southern, Mesa
# 2          Safeway - Mesa #1637
# 3  Greenfield & Inverness, Mesa
# 4       Safeway - Gilbert #1748
#
#                                                  url  \
# 0  https://www.starbucks.com/store-locator/store/...
# 1  https://www.starbucks.com/store-locator/store/...
# 2  https://www.starbucks.com/store-locator/store/...
# 3  https://www.starbucks.com/store-locator/store/...
# 4  https://www.starbucks.com/store-locator/store/...
#
#                   street_address     city state   zip_code country  \
# 0        1939 S Val Vista Dr, #D     Mesa    AZ  852047314      US
# 1  3550 E. Southern Avenue, #104     Mesa    AZ  852045683      US
# 2            3622 E Southern Ave     Mesa    AZ  852062504      US
# 3  1705 S. Greenfield Road, #101     Mesa    AZ  852063487      US
# 4             5137 E Baseline Rd  Gilbert    AZ  852342967      US
#
# ...

# %%
#pulling
clean_data = starbucks_data[['city','state','zip_code']]

clean_data.head()
# Out:
#       city state   zip_code
# 0     Mesa    AZ  852047314
# 1     Mesa    AZ  852045683
# 2     Mesa    AZ  852062504
# 3     Mesa    AZ  852063487
# 4  Gilbert    AZ  852342967

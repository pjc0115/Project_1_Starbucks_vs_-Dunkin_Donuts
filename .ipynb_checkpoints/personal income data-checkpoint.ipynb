# %%
import pandas as pd
import requests
import json
from pprint import pprint
from api_key import api_key

# %%
# Request data with API key
api_key = api_key
url = "https://api.stlouisfed.org/geofred/shapes/file?"
query_url = f"https://api.stlouisfed.org/geofred/series/data?series_id=WIPCPI&api_key={api_key}&file_type=json&date=2019-01-01"

# %%
# Display API call response
data = response.json()
pprint(data)
# Out:
# {'meta': {'data': {'2019': [{'code': '01',
#                              'region': 'Alabama',
#                              'series_id': 'ALPCPI',
#                              'value': '44102.0'},
#                             {'code': '02',
#                              'region': 'Alaska',
#                              'series_id': 'AKPCPI',
#                              'value': '62629.0'},
#                             {'code': '04',
#                              'region': 'Arizona',
#                              'series_id': 'AZPCPI',
#                              'value': '45975.0'},
#                             {'code': '05',
#                              'region': 'Arkansas',
#                              'series_id': 'ARPCPI',
#                              'value': '44582.0'},
#                             {'code': '06',
#                              'region': 'California',
#                              'series_id': 'CAPCPI',
#                              'value': '66745.0'},
#                             {'code': '08',
#                              'region': 'Colorado',
#                              'series_id': 'COPCPI',
#                              'value': '61159.0'},
#                             {'code': '09',
#                              'region': 'Connecticut',
#                              'series_id': 'CTPCPI',
#                              'value': '77273.0'},
#                             {'code': '10',
#                              'region': 'Delaware',
#                              'series_id': 'DEPCPI',
#                              'value': '54323.0'},
#                             {'code': '11',
#                              'region': 'District of Columbia',
#                              'series_id': 'DCPCPI',
#                              'value': '83111.0'},
#                             {'code': '12',
#                              'region': 'Florida',
#                              'series_id': 'FLPCPI',
#                              'value': '52391.0'},
#                             {'code': '13',
#                              'region': 'Georgia',
#                              'series_id': 'GAPCPI',
#                              'value': '48188.0'},
#                             {'code': '15',
#                              'region': 'Hawaii',
#                              'series_id': 'HIPCPI',
#                              'value': '57026.0'},
#                             {'code': '16',
#                              'region': 'Idaho',
#                              'series_id': 'IDPCPI',
#                              'value': '45917.0'},
#                             {'code': '17',
#                              'region': 'Illinois',
#                              'series_id': 'ILPCPI',
#                              'value': '58786.0'},
#                             {'code': '18',
#                              'region': 'Indiana',
#                              'series_id': 'INPCPI',
#                              'value': '48687.0'},
#                             {'code': '19',
#                              'region': 'Iowa',
#                              'series_id': 'IAPCPI',
#                              'value': '51791.0'},
#                             {'code': '20',
#                              'region': 'Kansas',
#                              'series_id': 'KSPCPI',
#                              'value': '53439.0'},
#                             {'code': '21',
#                              'region': 'Kentucky',
#                              'series_id': 'KYPCPI',
#                              'value': '43724.0'},
#                             {'code': '22',
#                              'region': 'Louisiana',
#                              'series_id': 'LAPCPI',
#                              'value': '47363.0'},
#                             {'code': '23',
#                              'region': 'Maine',
#                              'series_id': 'MEPCPI',
#                              'value': '50575.0'},
#                             {'code': '24',
#                              'region': 'Maryland',
#                              'series_id': 'MDPCPI',
#                              'value': '64541.0'},
#                             {'code': '25',
#                              'region': 'Massachusetts',
#                              'series_id': 'MAPCPI',
#                              'value': '74161.0'},
#                             {'code': '26',
#                              'region': 'Michigan',
#                              'series_id': 'MIPCPI',
#                              'value': '49238.0'},
#                             {'code': '27',
#                              'region': 'Minnesota',
#                              'series_id': 'MNPCPI',
#                              'value': '58830.0'},
#                             {'code': '28',
#                              'region': 'Mississippi',
#                              'series_id': 'MSPCPI',
#                              'value': '38887.0'},
#                             {'code': '29',
#                              'region': 'Missouri',
#                              'series_id': 'MOPCPI',
#                              'value': '48631.0'},
#                             {'code': '30',
#                              'region': 'Montana',
#                              'series_id': 'MTPCPI',
#                              'value': '49684.0'},
#                             {'code': '31',
#                              'region': 'Nebraska',
#                              'series_id': 'NEPCPI',
#                              'value': '54567.0'},
#                             {'code': '32',
#                              'region': 'Nevada',
#                              'series_id': 'NVPCPI',
#                              'value': '50985.0'},
#                             {'code': '33',
#                              'region': 'New Hampshire',
#                              'series_id': 'NHPCPI',
#                              'value': '63452.0'},
#                             {'code': '34',
#                              'region': 'New Jersey',
#                              'series_id': 'NJPCPI',
#                              'value': '70399.0'},
#                             {'code': '35',
#                              'region': 'New Mexico',
#                              'series_id': 'NMPCPI',
#                              'value': '43268.0'},
#                             {'code': '36',
#                              'region': 'New York',
#                              'series_id': 'NYPCPI',
#                              'value': '71682.0'},
#                             {'code': '37',
#                              'region': 'North Carolina',
#                              'series_id': 'NCPCPI',
#                              'value': '47706.0'},
#                             {'code': '38',
#                              'region': 'North Dakota',
#                              'series_id': 'NDPCPI',
#                              'value': '57108.0'},
#                             {'code': '39',
#                              'region': 'Ohio',
#                              'series_id': 'OHPCPI',
#                              'value': '50167.0'},
#                             {'code': '40',
#                              'region': 'Oklahoma',
#                              'series_id': 'OKPCPI',
#                              'value': '47297.0'},
#                             {'code': '41',
#                              'region': 'Oregon',
#                              'series_id': 'ORPCPI',
#                              'value': '53212.0'},
#                             {'code': '42',
#                              'region': 'Pennsylvania',
#                              'series_id': 'PAPCPI',
#                              'value': '58046.0'},
#                             {'code': '44',
#                              'region': 'Rhode Island',
#                              'series_id': 'RIPCPI',
#                              'value': '56426.0'},
#                             {'code': '45',
#                              'region': 'South Carolina',
#                              'series_id': 'SCPCPI',
#                              'value': '45359.0'},
#                             {'code': '46',
#                              'region': 'South Dakota',
#                              'series_id': 'SDPCPI',
#                              'value': '53812.0'},
#                             {'code': '47',
#                              'region': 'Tennessee',
#                              'series_id': 'TNPCPI',
#                              'value': '48676.0'},
#                             {'code': '48',
#                              'region': 'Texas',
#                              'series_id': 'TXPCPI',
#                              'value': '52829.0'},
#                             {'code': '49',
#                              'region': 'Utah',
#                              'series_id': 'UTPCPI',
#                              'value': '48978.0'},
#                             {'code': '50',
#                              'region': 'Vermont',
#                              'series_id': 'VTPCPI',
#                              'value': '55288.0'},
#                             {'code': '51',
#                              'region': 'Virginia',
#                              'series_id': 'VAPCPI',
#                              'value': '59509.0'},
#                             {'code': '53',
#                              'region': 'Washington',
#                              'series_id': 'WAPCPI',
#                              'value': '64766.0'},
#                             {'code': '54',
#                              'region': 'West Virginia',
#                              'series_id': 'WVPCPI',
#                              'value': '42242.0'},
#                             {'code': '55',
#                              'region': 'Wisconsin',
#                              'series_id': 'WIPCPI',
#                              'value': '53207.0'},
#                             {'code': '56',
#                              'region': 'Wyoming',
#                              'series_id': 'WYPCPI',
#                              'value': '62044.0'}]},
#           'frequency': 'Annual',
#           'region': 'state',
#           'seasonality': 'Not Seasonally Adjusted',
#           'title': 'Per Capita Personal Income by State (Dollars)',
#           'units': 'Dollars'}}

# %%
data_2019 = data["meta"]["data"]["2019"]
pprint(data_2019)
# Out:
# [{'code': '01', 'region': 'Alabama', 'series_id': 'ALPCPI', 'value': '44102.0'},
#  {'code': '02', 'region': 'Alaska', 'series_id': 'AKPCPI', 'value': '62629.0'},
#  {'code': '04', 'region': 'Arizona', 'series_id': 'AZPCPI', 'value': '45975.0'},
#  {'code': '05',
#   'region': 'Arkansas',
#   'series_id': 'ARPCPI',
#   'value': '44582.0'},
#  {'code': '06',
#   'region': 'California',
#   'series_id': 'CAPCPI',
#   'value': '66745.0'},
#  {'code': '08',
#   'region': 'Colorado',
#   'series_id': 'COPCPI',
#   'value': '61159.0'},
#  {'code': '09',
#   'region': 'Connecticut',
#   'series_id': 'CTPCPI',
#   'value': '77273.0'},
#  {'code': '10',
#   'region': 'Delaware',
#   'series_id': 'DEPCPI',
#   'value': '54323.0'},
#  {'code': '11',
#   'region': 'District of Columbia',
#   'series_id': 'DCPCPI',
#   'value': '83111.0'},
#  {'code': '12', 'region': 'Florida', 'series_id': 'FLPCPI', 'value': '52391.0'},
#  {'code': '13', 'region': 'Georgia', 'series_id': 'GAPCPI', 'value': '48188.0'},
#  {'code': '15', 'region': 'Hawaii', 'series_id': 'HIPCPI', 'value': '57026.0'},
#  {'code': '16', 'region': 'Idaho', 'series_id': 'IDPCPI', 'value': '45917.0'},
#  {'code': '17',
#   'region': 'Illinois',
#   'series_id': 'ILPCPI',
#   'value': '58786.0'},
#  {'code': '18', 'region': 'Indiana', 'series_id': 'INPCPI', 'value': '48687.0'},
#  {'code': '19', 'region': 'Iowa', 'series_id': 'IAPCPI', 'value': '51791.0'},
#  {'code': '20', 'region': 'Kansas', 'series_id': 'KSPCPI', 'value': '53439.0'},
#  {'code': '21',
#   'region': 'Kentucky',
#   'series_id': 'KYPCPI',
#   'value': '43724.0'},
#  {'code': '22',
#   'region': 'Louisiana',
#   'series_id': 'LAPCPI',
#   'value': '47363.0'},
#  {'code': '23', 'region': 'Maine', 'series_id': 'MEPCPI', 'value': '50575.0'},
#  {'code': '24',
#   'region': 'Maryland',
#   'series_id': 'MDPCPI',
#   'value': '64541.0'},
#  {'code': '25',
#   'region': 'Massachusetts',
#   'series_id': 'MAPCPI',
#   'value': '74161.0'},
#  {'code': '26',
#   'region': 'Michigan',
#   'series_id': 'MIPCPI',
#   'value': '49238.0'},
#  {'code': '27',
#   'region': 'Minnesota',
#   'series_id': 'MNPCPI',
#   'value': '58830.0'},
#  {'code': '28',
#   'region': 'Mississippi',
#   'series_id': 'MSPCPI',
#   'value': '38887.0'},
#  {'code': '29',
#   'region': 'Missouri',
#   'series_id': 'MOPCPI',
#   'value': '48631.0'},
#  {'code': '30', 'region': 'Montana', 'series_id': 'MTPCPI', 'value': '49684.0'},
#  {'code': '31',
#   'region': 'Nebraska',
#   'series_id': 'NEPCPI',
#   'value': '54567.0'},
#  {'code': '32', 'region': 'Nevada', 'series_id': 'NVPCPI', 'value': '50985.0'},
#  {'code': '33',
#   'region': 'New Hampshire',
#   'series_id': 'NHPCPI',
#   'value': '63452.0'},
#  {'code': '34',
#   'region': 'New Jersey',
#   'series_id': 'NJPCPI',
#   'value': '70399.0'},
#  {'code': '35',
#   'region': 'New Mexico',
#   'series_id': 'NMPCPI',
#   'value': '43268.0'},
#  {'code': '36',
#   'region': 'New York',
#   'series_id': 'NYPCPI',
#   'value': '71682.0'},
#  {'code': '37',
#   'region': 'North Carolina',
#   'series_id': 'NCPCPI',
#   'value': '47706.0'},
#  {'code': '38',
#   'region': 'North Dakota',
#   'series_id': 'NDPCPI',
#   'value': '57108.0'},
#  {'code': '39', 'region': 'Ohio', 'series_id': 'OHPCPI', 'value': '50167.0'},
#  {'code': '40',
#   'region': 'Oklahoma',
#   'series_id': 'OKPCPI',
#   'value': '47297.0'},
#  {'code': '41', 'region': 'Oregon', 'series_id': 'ORPCPI', 'value': '53212.0'},
#  {'code': '42',
#   'region': 'Pennsylvania',
#   'series_id': 'PAPCPI',
#   'value': '58046.0'},
#  {'code': '44',
#   'region': 'Rhode Island',
#   'series_id': 'RIPCPI',
#   'value': '56426.0'},
#  {'code': '45',
#   'region': 'South Carolina',
#   'series_id': 'SCPCPI',
#   'value': '45359.0'},
#  {'code': '46',
#   'region': 'South Dakota',
#   'series_id': 'SDPCPI',
#   'value': '53812.0'},
#  {'code': '47',
#   'region': 'Tennessee',
#   'series_id': 'TNPCPI',
#   'value': '48676.0'},
#  {'code': '48', 'region': 'Texas', 'series_id': 'TXPCPI', 'value': '52829.0'},
#  {'code': '49', 'region': 'Utah', 'series_id': 'UTPCPI', 'value': '48978.0'},
#  {'code': '50', 'region': 'Vermont', 'series_id': 'VTPCPI', 'value': '55288.0'},
#  {'code': '51',
#   'region': 'Virginia',
#   'series_id': 'VAPCPI',
#   'value': '59509.0'},
#  {'code': '53',
#   'region': 'Washington',
#   'series_id': 'WAPCPI',
#   'value': '64766.0'},
#  {'code': '54',
#   'region': 'West Virginia',
#   'series_id': 'WVPCPI',
#   'value': '42242.0'},
#  {'code': '55',
#   'region': 'Wisconsin',
#   'series_id': 'WIPCPI',
#   'value': '53207.0'},
#  {'code': '56', 'region': 'Wyoming', 'series_id': 'WYPCPI', 'value': '62044.0'}]

# %%
# Store state names and personal income to list
state = []
income = []
state_abv = []
# Make a for loop to go through the url response to get each state's personal income

for i in data_2019:
    state.append(i["series_id"][0:2])
    income.append(i["value"])
    #state_abv.append(i["series_id"][0:2])
    print(i["series_id"][0:2], i["value"])
# Out:
# AL 44102.0
# AK 62629.0
# AZ 45975.0
# AR 44582.0
# CA 66745.0
# CO 61159.0
# CT 77273.0
# DE 54323.0
# DC 83111.0
# FL 52391.0
# GA 48188.0
# HI 57026.0
# ID 45917.0
# IL 58786.0
# IN 48687.0
# IA 51791.0
# KS 53439.0
# KY 43724.0
# LA 47363.0
# ME 50575.0
# MD 64541.0
# MA 74161.0
# MI 49238.0
# MN 58830.0
# MS 38887.0
# MO 48631.0
# MT 49684.0
# NE 54567.0
# NV 50985.0
# NH 63452.0
# NJ 70399.0
# NM 43268.0
# NY 71682.0
# NC 47706.0
# ND 57108.0
# OH 50167.0
# OK 47297.0
# OR 53212.0
# PA 58046.0
# RI 56426.0
# SC 45359.0
# SD 53812.0
# TN 48676.0
# TX 52829.0
# UT 48978.0
# VT 55288.0
# VA 59509.0
# WA 64766.0
# WV 42242.0
# WI 53207.0
# WY 62044.0

# %%
# Display personal income per capital into dataframe
personal_income_df = pd.DataFrame({"State": state, "Income": income})
personal_income_df
# Out:
#    State   Income
# 0     AL  44102.0
# 1     AK  62629.0
# 2     AZ  45975.0
# 3     AR  44582.0
# 4     CA  66745.0
# 5     CO  61159.0
# 6     CT  77273.0
# 7     DE  54323.0
# 8     DC  83111.0
# 9     FL  52391.0
# 10    GA  48188.0
# 11    HI  57026.0
# 12    ID  45917.0
# 13    IL  58786.0
# 14    IN  48687.0
# 15    IA  51791.0
# 16    KS  53439.0
# 17    KY  43724.0
# 18    LA  47363.0
# 19    ME  50575.0
# 20    MD  64541.0
# 21    MA  74161.0
# 22    MI  49238.0
# 23    MN  58830.0
# 24    MS  38887.0
# 25    MO  48631.0
# 26    MT  49684.0
# 27    NE  54567.0
# 28    NV  50985.0
# 29    NH  63452.0
# 30    NJ  70399.0
# 31    NM  43268.0
# 32    NY  71682.0
# 33    NC  47706.0
# 34    ND  57108.0
# 35    OH  50167.0
# 36    OK  47297.0
# 37    OR  53212.0
# 38    PA  58046.0
# 39    RI  56426.0
# 40    SC  45359.0
# 41    SD  53812.0
# 42    TN  48676.0
# 43    TX  52829.0
# 44    UT  48978.0
# 45    VT  55288.0
# 46    VA  59509.0
# 47    WA  64766.0
# 48    WV  42242.0
# 49    WI  53207.0
# 50    WY  62044.0
